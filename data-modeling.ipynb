# %%
import pandas as pd
import os

from datetime import date
from pathlib import Path

# %%
path = Path("data")
entries = [path / entry for entry in os.listdir(path) if entry.endswith(".csv")]
list(entries)
# Out:
# [PosixPath('data/20231231_products.csv'),
#  PosixPath('data/20240104_products.csv'),
#  PosixPath('data/20240107_products.csv'),
#  PosixPath('data/20240111_products.csv')]

# %%
column_name_mapping = dict(
    codigo="code",
    marca="brand",
    nombre="name",
    precio="price",
    categoria="category",
)

def load_dataset(csv_path):
    df = pd.read_csv(csv_path)
    filename = csv_path.name
    dataset_date = date(int(filename[0:4]), int(filename[4:6]), int(filename[6:8]))
    df = df.assign(date=dataset_date)
    return df.rename(columns=column_name_mapping)

df = load_dataset(entries[-1])

df.tail()
# Out:
#          id    code                 brand                           name  \
# 3126  10260  124318  IMPORTADORA SUDAMERI            RAYOVAC PILA AAAX1U
# 3127    141    1429             A BALANZA          MILANESA DE CERDO XKG
# 3128     69     127             A BALANZA         MILANESAS DE CARNE XKG
# 3129     70     128             A BALANZA    MUSLO DE POLLO REBOZADO XKG
# 3130     61     106             A BALANZA  SUPREMA DE POLLO REBOZADA XKG
#
#        price    category        date
# 3126   395.0       PILAS  2024-01-11
# 3127  6699.0  PREPARADOS  2024-01-11
# 3128  6999.0  PREPARADOS  2024-01-11
# 3129  3799.0  PREPARADOS  2024-01-11
# 3130  3999.0  PREPARADOS  2024-01-11

# %%
duplicated_codes = df.code.value_counts()[lambda count: count > 1]
duplicated_codes
# Out:
# code
# 117140    2
# 118729    2
# 50003     2
# 102172    2
# 117350    2
# 124186    2
# 110560    2
# Name: count, dtype: int64

# %%
df[lambda item: item.code.isin(duplicated_codes.index)]
# Out:
#          id    code                 brand  \
# 413    1475  110560        EL ABASTECEDOR
# 414    4902  110560        EL ABASTECEDOR
# 2519   4359  124186       PLUSBELLE-ZORRO
# 2520  10160  124186       PLUSBELLE-ZORRO
# 2582   8231  102172        INVENTARIABLES
# 2583    656  102172        INVENTARIABLES
# 2585   5307  118729  COLGATE PALMOLIVE AR
# 2586   8396  118729  COLGATE PALMOLIVE AR
# 2798  10413  117140        PRECIOS JUSTOS
# 2799   2946  117140        PRECIOS JUSTOS
# 2843   9991   50003             A BALANZA
# 2844   1541   50003             A BALANZA
# 3049  10192  117350   S.C. JOHNSON&SON DE
# 3050   8297  117350   S.C. JOHNSON&SON DE
#
#                                             name   price  \
# 413               CEREALITAS TOSTADAS ARROZ X160  1050.0
# 414               CEREALITAS TOSTADAS ARROZ X160  1050.0
# 2519  PLUSBELLE SHAMPOO LAR.SALUDABLE D/P X300ML   599.0
# 2520  PLUSBELLE SHAMPOO LAR.SALUDABLE D/P X300ML   599.0
# 2582       COLGATE CREMA DENTAL ORIG.ANTIC.X180G  2105.0
# 2583       COLGATE CREMA DENTAL ORIG.ANTIC.X180G  2105.0
# 2585        COLGATE CREMA DENTAL T.CL.MINT X140G  4379.0
# 2586        COLGATE CREMA DENTAL T.CL.MINT X140G  4379.0
# 2798            GLADE AROMATIZANTE L/V RPTO 175G  5199.0
# 2799            GLADE AROMATIZANTE L/V RPTO 175G  5199.0
# 2843                       CABOS METALICOS CHAPA   670.0
# 2844                       CABOS METALICOS CHAPA   670.0
# 3049               GLADE LIMP.LIQ.M/D/CPO.X900ML  1399.0
# 3050               GLADE LIMP.LIQ.M/D/CPO.X900ML  1399.0
#
#                             category        date
# 413   GALLETAS / TOSTADAS / GRISINES  2024-01-11
# 414   GALLETAS / TOSTADAS / GRISINES  2024-01-11
# 2519             CUIDADO DEL CABELLO  2024-01-11
# 2520             CUIDADO DEL CABELLO  2024-01-11
# 2582                    CUIDADO ORAL  2024-01-11
# 2583                    CUIDADO ORAL  2024-01-11
# 2585                    CUIDADO ORAL  2024-01-11
# 2586                    CUIDADO ORAL  2024-01-11
# 2798       DESODORANTES DE AMBIENTES  2024-01-11
# 2799       DESODORANTES DE AMBIENTES  2024-01-11
# 2843            ELEMENTOS D/LIMPIEZA  2024-01-11
# 2844            ELEMENTOS D/LIMPIEZA  2024-01-11
# 3049     LIMPIEZA DE PISOS Y MUEBLES  2024-01-11
# 3050     LIMPIEZA DE PISOS Y MUEBLES  2024-01-11

# %%
categories = df.category.drop_duplicates().reset_index(drop=True).reset_index()
categories
# Out:
#      index                     category
# 0        0                      ACEITES
# 1        1                     ADEREZOS
# 2        2          APTOS PARA CELIACOS
# 3        3                      ARROCES
# 4        4                       AZUCAR
# ..     ...                          ...
# 132    132  LIMPIEZA DE PISOS Y MUEBLES
# 133    133       LIMPIEZA DEL AUTOMOTOR
# 134    134                      PAPELES
# 135    135                        PILAS
# 136    136                   PREPARADOS
#
# [137 rows x 2 columns]

# %%
brands = df.brand.drop_duplicates().reset_index(drop=True).reset_index()
brands
# Out:
#      index                            brand
# 0        0            MOLINO CAÃUELAS S.A.
# 1        1                   PRECIOS JUSTOS
# 2        2                   EL ABASTECEDOR
# 3        3             MOLINOS RIO DE LA PL
# 4        4             ACEITERA GENERAL DEH
# ..     ...                              ...
# 194    194             TEXTIL CATAMARCA S.A
# 195    195                        ROLL PACK
# 196    196                              TEA
# 197    197              ENERGIZER ARGENTINA
# 198    198  PAPELERA SAN ANDRES DE GILES SA
#
# [199 rows x 2 columns]

# %%
df_merged = pd.merge(pd.merge(df, brands, on="brand"), categories, on="category", suffixes=("_brand","_category"))
df_merged
# Out:
#          id    code                  brand  \
# 0      7508  114746  MOLINO CAÃUELAS S.A.
# 1      8147  112222  MOLINO CAÃUELAS S.A.
# 2      4241  112537  MOLINO CAÃUELAS S.A.
# 3      7274  121431  MOLINO CAÃUELAS S.A.
# 4       757  103100         PRECIOS JUSTOS
# ...     ...     ...                    ...
# 3126   3565  102139   WASSINGTON S.A.C.I.F
# 3127   7882  120599   WASSINGTON S.A.C.I.F
# 3128    652  102140   WASSINGTON S.A.C.I.F
# 3129  17876  150033    ENERGIZER ARGENTINA
# 3130   9233  122836    ENERGIZER ARGENTINA
#
#                                                name    price  \
# 0                 CAÃUELAS AC.OLI.INTEN.LATA.X500C  10715.0
# 1                  CAÃUELAS AC.OLIVA E/VIR.PETX500   9235.0
# 2             CAÃUELAS ACEITE OLIVA E/VIR LATAX500  10715.0
# 3                   PUREZA ACEITE GIRASOL PET X1.5L   2639.0
# 4                CAÃUELAS ACEITE GIRASOL PET X1.5L   2518.0
# ...                                             ...      ...
# 3126                    WASSINGTON POM.MARRON X30GR   2100.0
# 3127                 WASSINGTON POM.NEGRA CALZ.X60G   3500.0
# 3128                     WASSINGTON POM.NEGRA X30GR   2100.0
# 3129  ARMOR ALL CERA LIQUIDA ULTRA BRILLANTE X500ML   6559.0
# 3130             ARMOR ALL SH. C/CERA P/AUTO X473ML   5379.0
#
#                     category        date  index_brand  index_category
# 0                    ACEITES  2024-01-11            0               0
# 1                    ACEITES  2024-01-11            0               0
# 2                    ACEITES  2024-01-11            0               0
# 3                    ACEITES  2024-01-11            0               0
# 4                    ACEITES  2024-01-11            1               0
# ...                      ...         ...          ...             ...
# 3126                 CALZADO  2024-01-11          189             124
# 3127                 CALZADO  2024-01-11          189             124
# 3128                 CALZADO  2024-01-11          189             124
# 3129  LIMPIEZA DEL AUTOMOTOR  2024-01-11          197             133
# 3130  LIMPIEZA DEL AUTOMOTOR  2024-01-11          197             133
#
# [3131 rows x 9 columns]

# %%
products = df_merged[["code", "name", "index_brand", "index_category"]]
products
# Out:
#         code                                           name  index_brand  \
# 0     114746              CAÃUELAS AC.OLI.INTEN.LATA.X500C            0
# 1     112222               CAÃUELAS AC.OLIVA E/VIR.PETX500            0
# 2     112537          CAÃUELAS ACEITE OLIVA E/VIR LATAX500            0
# 3     121431                PUREZA ACEITE GIRASOL PET X1.5L            0
# 4     103100             CAÃUELAS ACEITE GIRASOL PET X1.5L            1
# ...      ...                                            ...          ...
# 3126  102139                    WASSINGTON POM.MARRON X30GR          189
# 3127  120599                 WASSINGTON POM.NEGRA CALZ.X60G          189
# 3128  102140                     WASSINGTON POM.NEGRA X30GR          189
# 3129  150033  ARMOR ALL CERA LIQUIDA ULTRA BRILLANTE X500ML          197
# 3130  122836             ARMOR ALL SH. C/CERA P/AUTO X473ML          197
#
#       index_category
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3126             124
# 3127             124
# 3128             124
# 3129             133
# 3130             133
#
# [3131 rows x 4 columns]

# %%
prices = df_merged[["code", "price"]]
prices
# Out:
#         code    price
# 0     114746  10715.0
# 1     112222   9235.0
# 2     112537  10715.0
# 3     121431   2639.0
# 4     103100   2518.0
# ...      ...      ...
# 3126  102139   2100.0
# 3127  120599   3500.0
# 3128  102140   2100.0
# 3129  150033   6559.0
# 3130  122836   5379.0
#
# [3131 rows x 2 columns]
